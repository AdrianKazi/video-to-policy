# %% [markdown]
# ### Imports

# %%
import torch
import torch.nn as nn
import numpy as np
import torch.optim as optim
import torch.nn.functional as F
import gym
from collections import deque
import random
import mlflow

# %% [markdown]
# ### Hyperparameters

# %%
LR_ACTOR = 3e-4
LR_CRITIC = 3e-4
REPLAY_BUFFER_SIZE = int(1e6)
BATCH_SIZE = 128
GAMMA = 0.99
MAX_EPISODES = 1000
MAX_STEPS = int(1e3)
TARGET_REWARD = 200
MIN_MEMORY = 1e4
TARGET_POLICY_CLIP = 0.5

TAU = 0.005 
POLICY_DELAY = 3 
TARGET_POLICY_NOISE = 0.3

# %% [markdown]
# ### Environment

# %%
env = gym.make('LunarLanderContinuous-v2')
state_dim = env.observation_space.shape[0] # state representation
action_dim = env.action_space.shape[0] # possible actions
max_action = float(env.action_space.high[0]) # max of one throttle 

print('state_dim:', state_dim)
print('action_dim:', action_dim)
print('max_action:', max_action)
# Out:
# state_dim: 8
# action_dim: 2
# max_action: 1.0

# %% [markdown]
# #### Neural Networks

# %%
class Actor(nn.Module):
    def __init__(self, state_dim, action_dim, max_action):
        super().__init__()

        self.fc1 = nn.Linear(state_dim, 512)
        # self.bn1 = nn.BatchNorm1d(512)
        self.fc2 = nn.Linear(512, 512)
        self.fc3 = nn.Linear(512, 256)
        self.fc4 = nn.Linear(256, action_dim)
        self.max_action = max_action

    def forward(self, state):
        x = torch.relu(self.fc1(state))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))
        x = torch.tanh(self.fc4(x))
        return self.max_action * x

# %%
actor = Actor(state_dim, action_dim, max_action)
actor
# Out:
# Actor(
#   (fc1): Linear(in_features=8, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=2, bias=True)
# )

# %%
class Critic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super().__init__()

        self.fc1 = nn.Linear(state_dim + action_dim, 512)
        # self.bn1 = nn.BatchNorm1d(512)
        self.fc2 = nn.Linear(512, 512)
        self.fc3 = nn.Linear(512, 256)
        self.q = nn.Linear(256, 1)

    def forward(self, state, action):
        state_action = torch.cat([state, action], dim=1)
        x = torch.relu(self.fc1(state_action))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))
        q_value = self.q(x)
        return q_value

# %%
class TwinCritic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super().__init__()

        # First Q-Network
        self.fc1_1 = nn.Linear(state_dim + action_dim, 512)
        self.fc2_1 = nn.Linear(512, 512)
        self.fc3_1 = nn.Linear(512, 256)
        self.q1 = nn.Linear(256, 1)

        # Second Q-Network
        self.fc1_2 = nn.Linear(state_dim + action_dim, 512)
        self.fc2_2 = nn.Linear(512, 512)
        self.fc3_2 = nn.Linear(512, 256)
        self.q2 = nn.Linear(256, 1)

    def forward(self, state, action):
        state_action = torch.cat([state, action], dim=1)

        # Compute Q1
        x1 = torch.relu(self.fc1_1(state_action))
        x1 = torch.relu(self.fc2_1(x1))
        x1 = torch.relu(self.fc3_1(x1))
        q1 = self.q1(x1)

        # Compute Q2
        x2 = torch.relu(self.fc1_2(state_action))
        x2 = torch.relu(self.fc2_2(x2))
        x2 = torch.relu(self.fc3_2(x2))
        q2 = self.q2(x2)

        return q1, q2

# %%
# critic = Critic(state_dim, action_dim)
critic = TwinCritic(state_dim, action_dim)
critic
# Out:
# TwinCritic(
#   (fc1_1): Linear(in_features=10, out_features=512, bias=True)
#   (fc2_1): Linear(in_features=512, out_features=512, bias=True)
#   (fc3_1): Linear(in_features=512, out_features=256, bias=True)
#   (q1): Linear(in_features=256, out_features=1, bias=True)
#   (fc1_2): Linear(in_features=10, out_features=512, bias=True)
#   (fc2_2): Linear(in_features=512, out_features=512, bias=True)
#   (fc3_2): Linear(in_features=512, out_features=256, bias=True)
#   (q2): Linear(in_features=256, out_features=1, bias=True)
# )

# %% [markdown]
# ### Agents

# %%
class OrnsteinUhlenbeckActionNoise:
    def __init__(self, mean, sigma=0.2, theta=0.15, dt=1e-2, x0=None):
        self.mean = mean
        self.sigma = sigma
        self.theta = theta
        self.dt = dt
        self.x0 = x0
        self.reset()

    def reset(self):
        self.x_prev = self.x0 if self.x0 is not None else np.zeros_like(self.mean)

    def __call__(self):
        noise = self.theta * (self.mean - self.x_prev) * self.dt + self.sigma * np.sqrt(self.dt) * np.random.randn(*self.mean.shape)
        self.x_prev += noise
        return self.x_prev

class DDPG_Agent():
    
    def __init__(self, state_dim, action_dim, max_action):
        # Actor
        self.actor = Actor(state_dim, action_dim, max_action)
        self.actor_target = Actor(state_dim, action_dim, max_action)
        actor_target_state_dict = self.actor_target.state_dict()
        self.actor_target.load_state_dict(actor_target_state_dict)

        # Critic
        self.critic = Critic(state_dim, action_dim)
        self.critic_target = Critic(state_dim, action_dim)
        critic_target_state_dict = self.critic_target.state_dict()
        self.critic_target.load_state_dict(critic_target_state_dict)

        # Optimizer
        self.actor_optimizer = optim.Adam(self.actor.parameters(), lr=LR_ACTOR)
        self.critic_optimizer = optim.Adam(self.critic.parameters(), lr=LR_CRITIC)

        # Other
        self.memory = deque(maxlen=REPLAY_BUFFER_SIZE)

        # Max Action
        self.max_action = max_action
        
        # Device
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.actor.to(self.device)
        self.actor_target.to(self.device)
        self.critic.to(self.device)
        self.critic_target.to(self.device)  

        # OU Noise for exploration
        self.noise = OrnsteinUhlenbeckActionNoise(mean=np.zeros(action_dim), sigma=0.2) 

    def select_action(self, state, noise=0.1):
        # Convert state to tensor
        state = torch.FloatTensor(state).to(self.device)

        # Get action from actor network)
        action = self.actor(state).cpu().detach().numpy()

        # Add exploration noise
        action += self.noise()

        # Clip action to return an action within valid range of possible actions
        return np.clip(action, -self.max_action, self.max_action)
    
    def store_experience(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def train(self):
        if len(self.memory) < MIN_MEMORY:
            return # We need to wait until enough experience is collected
        
        # Sample from replay buffer
        batch = random.sample(self.memory, BATCH_SIZE)
        states, actions, rewards, next_states, dones = zip(*batch)

        # Convert to tensors
        states = torch.FloatTensor(states).to(self.device)
        actions = torch.FloatTensor(actions).to(self.device)
        rewards = torch.FloatTensor(rewards).to(self.device)
        next_states = torch.FloatTensor(next_states).to(self.device)
        dones = torch.FloatTensor(dones).to(self.device)

        # Compute targets without tracking gradients
        with torch.no_grad():
            next_actions = self.actor_target(next_states)
            target_q = rewards + GAMMA * (1-dones) * self.critic_target(next_states, next_actions)

        # Critic Step
        q_values = self.critic(states, actions)
        critic_loss = nn.MSELoss()(q_values, target_q)

        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.critic.parameters(), 1.0)
        self.critic_optimizer.step()

        # Actor Step
        actor_loss = -self.critic(states, self.actor(states)).mean()

        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.actor.parameters(), 1.0)
        self.actor_optimizer.step()

        # Soft Update Target Networks
        for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
            # Update target parameters in place
            target_param.data.copy_(TAU * param.data + (1-TAU) * target_param.data)

        for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
            # Update target params in place
            target_param.data.copy_(TAU * param.data + (1 - TAU) * target_param.data)


class TD3_Agent():
    def __init__(self, state_dim, action_dim, max_action):
        # Actor
        self.actor = Actor(state_dim, action_dim, max_action)
        self.actor_target = Actor(state_dim, action_dim, max_action)
        self.actor_target.load_state_dict(self.actor.state_dict())

        # Twin Critics
        self.critic = TwinCritic(state_dim, action_dim)
        self.critic_target = TwinCritic(state_dim, action_dim)
        self.critic_target.load_state_dict(self.critic.state_dict())

        # Optimizers
        self.actor_optimizer = optim.Adam(self.actor.parameters(), lr=LR_ACTOR)
        self.critic_optimizer = optim.Adam(self.critic.parameters(), lr=LR_CRITIC)

        # Exploration Noise
        self.noise = OrnsteinUhlenbeckActionNoise(mean=np.zeros(action_dim), sigma=0.2) 

        # Replay Buffer
        self.memory = deque(maxlen=REPLAY_BUFFER_SIZE)

        # Max Action
        self.max_action = max_action

        # Training step counter
        self.train_step = 0 

        # Device
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.actor.to(self.device)
        self.actor_target.to(self.device)
        self.critic.to(self.device)
        self.critic_target.to(self.device)


    def select_action(self, state, noise=0.1):
        state = torch.FloatTensor(state).to(self.device)
        action = self.actor(state).cpu().detach().numpy()

        # Add Gaussian noise
        action += np.random.normal(0, noise, size=action.shape)
        return np.clip(action, -self.max_action, self.max_action)

    def store_experience(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))


    def train(self):
        if len(self.memory) < MIN_MEMORY:
            return  # Wait until enough experience is collected
        
        # Sample batch from replay buffer
        batch = random.sample(self.memory, BATCH_SIZE)
        states, actions, rewards, next_states, dones = zip(*batch)

        # Convert to tensors
        states = torch.FloatTensor(states).to(self.device)
        actions = torch.FloatTensor(actions).to(self.device)
        rewards = torch.FloatTensor(rewards).unsqueeze(1).to(self.device)
        next_states = torch.FloatTensor(next_states).to(self.device)
        dones = torch.FloatTensor(dones).unsqueeze(1).to(self.device)

        # Target Policy Smoothing: Add noise to target actions
        with torch.no_grad():
            noise = torch.clamp(
                torch.normal(0, TARGET_POLICY_CLIP, size=actions.shape).to(self.device), -0.5, 0.5
            )
            next_actions = self.actor_target(next_states) + noise
            next_actions = torch.clamp(next_actions, -self.max_action, self.max_action)

            # Compute both target Q-values
            q1_next, q2_next = self.critic_target(next_states, next_actions)
            target_q = rewards + GAMMA * (1 - dones) * torch.min(q1_next, q2_next)

        # Compute current Q-values from twin critics
        q1, q2 = self.critic(states, actions)
        mlflow.log_metric('Q1_Value', q1.mean().item(), step=self.train_step)
        mlflow.log_metric('Q2_values', q2.mean().item(), step=self.train_step)
        
        # Critic Loss (Huber loss instead of MSE for stability)
        critic_loss = F.smooth_l1_loss(q1, target_q) + F.smooth_l1_loss(q2, target_q)
        mlflow.log_metric('Critic_Loss', critic_loss.item(), self.train_step)

        # Update Critic
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.critic.parameters(), 1.0)
        self.critic_optimizer.step()

        # TD Error (Bellman Residual)
        td_error = (target_q - q1).mean().abs().item()
        mlflow.log_metric('TD_Error', td_error, self.train_step)

        # Entropy Action
        action_variance = actions.var().item() # Variance of selected actions
        mlflow.log_metric('Entropy_Actions', action_variance, self.train_step)

        # Delayed Actor Updates
        if self.train_step % POLICY_DELAY == 0:
            # Compute actor loss (use Q1 only)
            actor_loss = -self.critic(states, self.actor(states))[0].mean()
            mlflow.log_metric('Policy_Loss', actor_loss.item(), self.train_step)

            # Update Actor
            self.actor_optimizer.zero_grad()
            actor_loss.backward()
            self.actor_optimizer.step()

            # Soft Update Target Networks
            for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
                target_param.data.copy_(TAU * param.data + (1 - TAU) * target_param.data)

            for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
                target_param.data.copy_(TAU * param.data + (1 - TAU) * target_param.data)

        self.train_step += 1

# %% [markdown]
# ### Train Loop

# %%
import datetime

date = datetime.datetime.now().strftime("%Y-%m-%d")
NAME = "TARGET_POLICY_NOISE_0.3"
TRAIN_RUN_NAME = f"{NAME}__train"

# %%
env = gym.make('LunarLanderContinuous-v2', render_mode='none')
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])

agent = TD3_Agent(state_dim, action_dim, max_action)
reward_history = []

try:
    if mlflow.active_run():
        run_id = mlflow.active_run().info.run_id
        print(f"Attempting to end active run: {run_id}")
        mlflow.end_run()
except Exception as e:
    print(f"Warning: Tried to end an inactive run. Skipping. Error: {e}")

mlflow.set_experiment('TARGET_POLICY_NOISE_')

mlflow.set_tracking_uri("file:./mlruns") 
mlflow.autolog(disable=True)

with mlflow.start_run(run_name=TRAIN_RUN_NAME, nested=True):
    mlflow.log_param('algorithm', 'DDPG')
    mlflow.log_param('lr_actor', LR_ACTOR)
    mlflow.log_param('lr_critic', LR_CRITIC)
    mlflow.log_param('replay_buffer_size', REPLAY_BUFFER_SIZE)
    mlflow.log_param('batch_size', BATCH_SIZE)
    mlflow.log_param('gamma',GAMMA)
    mlflow.log_param('tau_polyak_averaging_factor',TAU)
    mlflow.log_param('max_episodes', MAX_EPISODES)
    mlflow.log_param('max_steps', MAX_STEPS)
    mlflow.log_param('target_reward', TARGET_REWARD)

    for episode in range(MAX_EPISODES):
        state, _ = env.reset()
        episode_reward = 0

        for step in range(MAX_STEPS):
            action = agent.select_action(state, noise=0.1)
            next_state, reward, done, _, _ = env.step(action)
            agent.store_experience(state, action, reward, next_state, done)
            agent.train()
            episode_reward += reward
            state = next_state
            if done:
                break

        reward_history.append(episode_reward)
        avg_last_10_rewards = np.mean(reward_history[-10:])
        
        print(f'Episode rewards: {episode + 1}, Reward: {episode_reward}')

        mlflow.log_metric('train_episode_reward', episode_reward, step=episode)
        mlflow.log_metric('train_avg_last_10_rewards', avg_last_10_rewards, step=episode)

        if len(reward_history) >= 100:
            if np.mean(reward_history[-100:]) >= TARGET_REWARD:
                print('TARGET_REWARD Achieved!')
                break

    env.close()

    actor_path = f'./models/{TRAIN_RUN_NAME}.pth'
    torch.save(agent.actor.state_dict(), actor_path)
    mlflow.log_artifact(actor_path)
# Out:
# Episode rewards: 1, Reward: -113.75207626886998
# /Users/adriankazi/.pyenv/versions/3.12.1/lib/python3.12/site-packages/gym/envs/registration.py:623: UserWarning: WARN: The environment is being initialised with mode (none) that is not in the possible render_modes (['human', 'rgb_array']).
#   logger.warn(
# Episode rewards: 2, Reward: -203.35956896298825
# Episode rewards: 3, Reward: -94.52991072199298
# Episode rewards: 4, Reward: -160.3375707313028
# Episode rewards: 5, Reward: -140.84220453295157
# Episode rewards: 6, Reward: -125.71520649382904
# Episode rewards: 7, Reward: -197.9437185845687
# Episode rewards: 8, Reward: -117.47538305013387
# Episode rewards: 9, Reward: -137.0973572535533
# Episode rewards: 10, Reward: -145.84867194888884
# Episode rewards: 11, Reward: -98.23833604927097
# Episode rewards: 12, Reward: -61.622133400520234
# Episode rewards: 13, Reward: -196.84411214049987
# Episode rewards: 14, Reward: -104.53791182121611
# Episode rewards: 15, Reward: -115.36450856388898
# Episode rewards: 16, Reward: -104.05479752437034
# Episode rewards: 17, Reward: -137.9301756414899
# Episode rewards: 18, Reward: -38.611326281585676
# Episode rewards: 19, Reward: -86.57869522626444
# Episode rewards: 20, Reward: -91.31812409344724
# Episode rewards: 21, Reward: -13.320688473300521
# Episode rewards: 22, Reward: -120.63373780625922
# Episode rewards: 23, Reward: -234.48841321845845
# Episode rewards: 24, Reward: -104.0402987938223
# Episode rewards: 25, Reward: -136.28219311528008
# Episode rewards: 26, Reward: -231.1325991424201
# Episode rewards: 27, Reward: -100.11892145968287
# Episode rewards: 28, Reward: -43.60201504774166
# Episode rewards: 29, Reward: -31.2449194202663
# Episode rewards: 30, Reward: -144.21935121988903
# Episode rewards: 31, Reward: -106.78685907416356
# Episode rewards: 32, Reward: 27.997391583814476
# Episode rewards: 33, Reward: -93.5514050191779
# Episode rewards: 34, Reward: -286.69623509132373
# Episode rewards: 35, Reward: -194.38371364725805
# Episode rewards: 36, Reward: -101.66136173070844
# Episode rewards: 37, Reward: -145.64689233654929
# Episode rewards: 38, Reward: -130.54031483493
# Episode rewards: 39, Reward: -142.51682805274706
# Episode rewards: 40, Reward: -193.0351138900341
# Episode rewards: 41, Reward: -91.38372103288992
# Episode rewards: 42, Reward: -99.41895771840245
# Episode rewards: 43, Reward: -76.18381819431956
# Episode rewards: 44, Reward: -79.29849104365313
# Episode rewards: 45, Reward: -219.86637744749194
# Episode rewards: 46, Reward: -55.05566767495228
# Episode rewards: 47, Reward: -157.37870679664684
# Episode rewards: 48, Reward: -152.05327687562493
# Episode rewards: 49, Reward: -101.10484584883632
# Episode rewards: 50, Reward: -80.60354117104595
# Episode rewards: 51, Reward: -124.28880854622429
# Episode rewards: 52, Reward: -124.59786241110966
# Episode rewards: 53, Reward: -201.13093380848028
# Episode rewards: 54, Reward: -196.35423762320315
# Episode rewards: 55, Reward: -175.74144193296576
# Episode rewards: 56, Reward: -125.48397701511192
# Episode rewards: 57, Reward: -102.67738139650831
# Episode rewards: 58, Reward: -141.5874436242484
# Episode rewards: 59, Reward: -84.48357238996084
# Episode rewards: 60, Reward: -109.85138139218904
# Episode rewards: 61, Reward: -141.13416518133118
# Episode rewards: 62, Reward: 1.2656124719425463
# Episode rewards: 63, Reward: -107.27051653707755
# Episode rewards: 64, Reward: -85.32500863016037
# Episode rewards: 65, Reward: -71.19308031125423
# Episode rewards: 66, Reward: -362.2113678902331
# Episode rewards: 67, Reward: -213.368990367723
# Episode rewards: 68, Reward: -133.9235409064856
# Episode rewards: 69, Reward: -99.81596365970255
# Episode rewards: 70, Reward: -340.9959814242934
# Episode rewards: 71, Reward: -107.73466769951558
# Episode rewards: 72, Reward: -277.39952316857386
# Episode rewards: 73, Reward: -80.12923260019625
# Episode rewards: 74, Reward: -261.4059786730243
# Episode rewards: 75, Reward: -222.87686090899294
# Episode rewards: 76, Reward: -191.8629518993693
# Episode rewards: 77, Reward: -124.06540950309844
# Episode rewards: 78, Reward: -269.3122487923755
# Episode rewards: 79, Reward: -93.60231707071094
# Episode rewards: 80, Reward: -67.68481498779968
# Episode rewards: 81, Reward: -126.556576700803
# Episode rewards: 82, Reward: -264.22339106899443
# Episode rewards: 83, Reward: -221.07471077374126
# Episode rewards: 84, Reward: -182.55619540203338
# Episode rewards: 85, Reward: -213.54066604728192
# Episode rewards: 86, Reward: -77.59192489638761
# Episode rewards: 87, Reward: -271.25724375661616
# Episode rewards: 88, Reward: -208.49513800221277
# Episode rewards: 89, Reward: -81.34441734548825
# Episode rewards: 90, Reward: -91.0207873652618
# Episode rewards: 91, Reward: -99.28586367652888
# Episode rewards: 92, Reward: -70.87670863377959
# Episode rewards: 93, Reward: -194.69352345064306
# Episode rewards: 94, Reward: -113.80113674953103
# Episode rewards: 95, Reward: -113.11378416737678
# Episode rewards: 96, Reward: 3.3410856369634843
# Episode rewards: 97, Reward: -199.34669774328177
# Episode rewards: 98, Reward: -125.69660650936733
# Episode rewards: 99, Reward: -76.79250477066714
# Episode rewards: 100, Reward: -106.4554452474695
# Episode rewards: 101, Reward: -133.6884490548833
# Episode rewards: 102, Reward: -78.56415390626165
# Episode rewards: 103, Reward: -137.41614699913634
# Episode rewards: 104, Reward: -165.76582834269104
# Episode rewards: 105, Reward: -45.679054212846495
# Episode rewards: 106, Reward: -139.55801949198678
# Episode rewards: 107, Reward: -127.28965624027838
# Episode rewards: 108, Reward: -84.32757423479465
# Episode rewards: 109, Reward: -136.95577180813905
# Episode rewards: 110, Reward: -440.8660449432058
# Episode rewards: 111, Reward: -299.64868665224856
# Episode rewards: 112, Reward: -831.3479415083391
# Episode rewards: 113, Reward: -323.68165890583447
# Episode rewards: 114, Reward: -206.9507911384998
# Episode rewards: 115, Reward: -270.02265342122337
# Episode rewards: 116, Reward: -198.71764957883752
# Episode rewards: 117, Reward: -357.51845065811466
# Episode rewards: 118, Reward: -205.87529669295154
# Episode rewards: 119, Reward: -257.2483501504095
# Episode rewards: 120, Reward: -714.911640863751
# Episode rewards: 121, Reward: -589.3465564131807
# Episode rewards: 122, Reward: -231.95595804082177
# Episode rewards: 123, Reward: -236.35785515855412
# Episode rewards: 124, Reward: -206.14921801469575
# Episode rewards: 125, Reward: -263.42617669074343
# Episode rewards: 126, Reward: -152.31471142132432
# Episode rewards: 127, Reward: -107.56382421767354
# Episode rewards: 128, Reward: -203.19450093201434
# Episode rewards: 129, Reward: -202.2513982608674
# Episode rewards: 130, Reward: -181.75331873732364
# Episode rewards: 131, Reward: -198.81506468309928
# Episode rewards: 132, Reward: -41.03490672823884
# Episode rewards: 133, Reward: -110.30628351186566
# Episode rewards: 134, Reward: -186.69636798562723
# Episode rewards: 135, Reward: -290.5079019336479
# Episode rewards: 136, Reward: -321.61826945214875
# Episode rewards: 137, Reward: -232.65383066992817
# Episode rewards: 138, Reward: -279.20206848238456
# Episode rewards: 139, Reward: -261.30303635291875
# Episode rewards: 140, Reward: -178.08453342981545
# Episode rewards: 141, Reward: -161.83503395975947
# Episode rewards: 142, Reward: -160.9420630405678
# Episode rewards: 143, Reward: -115.68439094952367
# Episode rewards: 144, Reward: -54.86236255451712
# Episode rewards: 145, Reward: -92.70773621659029
# Episode rewards: 146, Reward: -136.83850155652982
# Episode rewards: 147, Reward: -104.94993132724078
# Episode rewards: 148, Reward: -125.0148180542955
# Episode rewards: 149, Reward: -140.63387309056344
# Episode rewards: 150, Reward: -130.06847488539626
# Episode rewards: 151, Reward: -61.6931537441409
# Episode rewards: 152, Reward: -141.9023214952957
# Episode rewards: 153, Reward: -82.2175471024538
# Episode rewards: 154, Reward: -131.5706342063803
# Episode rewards: 155, Reward: -114.00220316654868
# Episode rewards: 156, Reward: -131.38343868266836
# Episode rewards: 157, Reward: -68.20905450900595
# Episode rewards: 158, Reward: -97.89720896995044
# Episode rewards: 159, Reward: -133.10888205482783
# Episode rewards: 160, Reward: -116.12741449396141
# Episode rewards: 161, Reward: -145.8402140194618
# Episode rewards: 162, Reward: -103.49954984160321
# Episode rewards: 163, Reward: -120.43751441626917
# Episode rewards: 164, Reward: -89.91591764631255
# Episode rewards: 165, Reward: -112.522101313121
# Episode rewards: 166, Reward: -79.93216521987759
# Episode rewards: 167, Reward: -95.51558930543965
# Episode rewards: 168, Reward: -102.27651636669214
# Episode rewards: 169, Reward: -60.91144463920001
# Episode rewards: 170, Reward: -129.56036330454964
# Episode rewards: 171, Reward: -94.15265441167203
# Episode rewards: 172, Reward: -85.98284767719424
# Episode rewards: 173, Reward: -109.06611637554131
# Episode rewards: 174, Reward: -181.91580390132054
# Episode rewards: 175, Reward: -130.71753843907385
# Episode rewards: 176, Reward: -35.86297788051805
# Episode rewards: 177, Reward: -132.02018634409347
# Episode rewards: 178, Reward: -73.15255966086619
# Episode rewards: 179, Reward: -133.14069272180177
# Episode rewards: 180, Reward: -154.98638266733116
# Episode rewards: 181, Reward: -122.39036746693503
# Episode rewards: 182, Reward: -167.17464522069199
# Episode rewards: 183, Reward: -123.64952741031192
# Episode rewards: 184, Reward: -68.07635896564317
# Episode rewards: 185, Reward: -88.83367299371753
# Episode rewards: 186, Reward: -120.91704645505537
# Episode rewards: 187, Reward: -103.88615676827156
# Episode rewards: 188, Reward: -51.08227830630602
# Episode rewards: 189, Reward: -56.3029555910473
# Episode rewards: 190, Reward: -102.01845274500889
# Episode rewards: 191, Reward: -69.55971412198696
# Episode rewards: 192, Reward: -109.92066897254571
# Episode rewards: 193, Reward: -31.430583448786635
# Episode rewards: 194, Reward: -87.74136452782265
# Episode rewards: 195, Reward: -85.89324633931211
# Episode rewards: 196, Reward: -79.92246193496449
# Episode rewards: 197, Reward: -68.09626798452487
# Episode rewards: 198, Reward: -76.62509335831031
# Episode rewards: 199, Reward: -100.49053458426792
# Episode rewards: 200, Reward: -101.55301655358639
# Episode rewards: 201, Reward: -79.13686546513058
# Episode rewards: 202, Reward: -193.5090966442276
# Episode rewards: 203, Reward: -90.40849315651971
# Episode rewards: 204, Reward: -17.388655776422173
# Episode rewards: 205, Reward: -89.2339299437127
# Episode rewards: 206, Reward: -82.51830708051224
# Episode rewards: 207, Reward: -109.25305883248011
# Episode rewards: 208, Reward: -48.85863535043655
# Episode rewards: 209, Reward: -75.981922883318
# Episode rewards: 210, Reward: -43.995039641309546
# Episode rewards: 211, Reward: -49.554987133613345
# Episode rewards: 212, Reward: -56.64926935791288
# Episode rewards: 213, Reward: -47.68859071788677
# Episode rewards: 214, Reward: -46.60294432684817
# Episode rewards: 215, Reward: -92.20529468315448
# Episode rewards: 216, Reward: -46.10926612056066
# Episode rewards: 217, Reward: -26.74405017200915
# Episode rewards: 218, Reward: -13.291663166448142
# Episode rewards: 219, Reward: -71.51319665228888
# Episode rewards: 220, Reward: -87.79642164094643
# Episode rewards: 221, Reward: -71.07339463051298
# Episode rewards: 222, Reward: -27.032136968458662
# Episode rewards: 223, Reward: -0.8796941785187944
# Episode rewards: 224, Reward: -17.264124258604422
# Episode rewards: 225, Reward: -17.938412478025764
# Episode rewards: 226, Reward: -84.1478501290952
# Episode rewards: 227, Reward: -20.572262416373142
# Episode rewards: 228, Reward: -85.9362239273556
# Episode rewards: 229, Reward: -21.181194470059655
# Episode rewards: 230, Reward: -83.48793847539602
# Episode rewards: 231, Reward: -46.449816361236564
# Episode rewards: 232, Reward: -54.29661022140416
# Episode rewards: 233, Reward: -50.82358993831332
# Episode rewards: 234, Reward: -32.51333832277782
# Episode rewards: 235, Reward: -43.63234966063454
# Episode rewards: 236, Reward: -53.706164449374825
# Episode rewards: 237, Reward: -55.74799017246152
# Episode rewards: 238, Reward: -20.237851724109085
# Episode rewards: 239, Reward: -42.71662068758227
# Episode rewards: 240, Reward: 172.85959747412187
# Episode rewards: 241, Reward: -140.02622765407122
# Episode rewards: 242, Reward: -1.512734467640802
# Episode rewards: 243, Reward: -0.7762980606270109
# Episode rewards: 244, Reward: -74.30993260317496
# Episode rewards: 245, Reward: -60.524597032502946
# Episode rewards: 246, Reward: 27.626688924635406
# Episode rewards: 247, Reward: -64.7234204388114
# Episode rewards: 248, Reward: 114.69667284934934
# Episode rewards: 249, Reward: -6.344258279384818
# Episode rewards: 250, Reward: 6.3701511678160845
# Episode rewards: 251, Reward: -16.168790801156913
# Episode rewards: 252, Reward: 130.90599427712525
# Episode rewards: 253, Reward: 18.55338404374375
# Episode rewards: 254, Reward: 123.25829358374546
# Episode rewards: 255, Reward: 216.11261083219017
# Episode rewards: 256, Reward: -27.396664778201682
# Episode rewards: 257, Reward: -6.7031584864743365
# Episode rewards: 258, Reward: -127.27460715124916
# Episode rewards: 259, Reward: -7.3532176982684545
# Episode rewards: 260, Reward: 215.31078282625822
# Episode rewards: 261, Reward: 51.351427618226474
# Episode rewards: 262, Reward: -20.80546282726513
# Episode rewards: 263, Reward: 37.53479016449555
# Episode rewards: 264, Reward: 65.89476339857008
# Episode rewards: 265, Reward: -18.667607084838508
# Episode rewards: 266, Reward: 30.205712180613524
# Episode rewards: 267, Reward: 32.81399294178016
# Episode rewards: 268, Reward: 20.579854304695214
# Episode rewards: 269, Reward: -65.2940300157871
# Episode rewards: 270, Reward: -41.75999536023189
# Episode rewards: 271, Reward: -39.10922111208743
# Episode rewards: 272, Reward: -9.848276674294517
# Episode rewards: 273, Reward: -11.115975853294511
# Episode rewards: 274, Reward: -28.694996403556907
# Episode rewards: 275, Reward: -24.774817269922764
# Episode rewards: 276, Reward: 273.3235230733636
# Episode rewards: 277, Reward: -23.112156326999216
# Episode rewards: 278, Reward: -8.988431234918613
# Episode rewards: 279, Reward: -2.700322574117309
# Episode rewards: 280, Reward: -48.76244703768928
# Episode rewards: 281, Reward: -17.838440532459437
# Episode rewards: 282, Reward: -71.9790713633107
# Episode rewards: 283, Reward: -15.90170158694086
# Episode rewards: 284, Reward: -69.07591770713154
# Episode rewards: 285, Reward: -5.2952658365719785
# Episode rewards: 286, Reward: -14.364965688081517
# Episode rewards: 287, Reward: -27.93865018099718
# Episode rewards: 288, Reward: -3.6938709399094307
# Episode rewards: 289, Reward: -64.52117040314057
# Episode rewards: 290, Reward: -19.23242708421773
# Episode rewards: 291, Reward: -28.279886061850206
# Episode rewards: 292, Reward: -17.26683478501368
# Episode rewards: 293, Reward: 24.429357130039133
# Episode rewards: 294, Reward: 274.98169059577793
# Episode rewards: 295, Reward: 154.3742753449699
# Episode rewards: 296, Reward: -23.392722143303377
# Episode rewards: 297, Reward: -27.56874996487651
# Episode rewards: 298, Reward: 163.36944072199563
# Episode rewards: 299, Reward: -48.44395366691995
# Episode rewards: 300, Reward: 4.969397759025284
# Episode rewards: 301, Reward: 4.9945669008070315
# Episode rewards: 302, Reward: 13.144129178463894
# Episode rewards: 303, Reward: -8.457054487622855
# Episode rewards: 304, Reward: 155.95861290599768
# Episode rewards: 305, Reward: -28.517263864212914
# Episode rewards: 306, Reward: 285.68899155837335
# Episode rewards: 307, Reward: 240.05117261109518
# Episode rewards: 308, Reward: -36.0588668720885
# Episode rewards: 309, Reward: 9.622184167149513
# Episode rewards: 310, Reward: 216.3327579803223
# Episode rewards: 311, Reward: 183.98427381952445
# Episode rewards: 312, Reward: -1.3583995989549629
# Episode rewards: 313, Reward: 151.52466350552683
# Episode rewards: 314, Reward: -47.07250587443298
# Episode rewards: 315, Reward: 230.85844157888084
# Episode rewards: 316, Reward: 228.11840327131998
# Episode rewards: 317, Reward: -26.123153856522627
# Episode rewards: 318, Reward: 35.60299641619886
# Episode rewards: 319, Reward: -15.365857985529358
# Episode rewards: 320, Reward: -90.84176292029163
# Episode rewards: 321, Reward: -17.618749226694007
# Episode rewards: 322, Reward: 230.2099960049535
# Episode rewards: 323, Reward: 6.770753663232238
# Episode rewards: 324, Reward: -6.64969795008725
# Episode rewards: 325, Reward: 175.2189233015378
# Episode rewards: 326, Reward: 182.61160171151496
# Episode rewards: 327, Reward: 23.725730392089993
# Episode rewards: 328, Reward: 171.32253639106688
# Episode rewards: 329, Reward: 2.869223855543928
# Episode rewards: 330, Reward: -33.38473250803053
# Episode rewards: 331, Reward: 223.6970456869968
# Episode rewards: 332, Reward: -0.43067456469865295
# Episode rewards: 333, Reward: 224.88184335032616
# Episode rewards: 334, Reward: -15.538351344379159
# Episode rewards: 335, Reward: 9.329202979526626
# Episode rewards: 336, Reward: 188.43177206284864
# Episode rewards: 337, Reward: -12.759484955685892
# Episode rewards: 338, Reward: 259.5212138588902
# Episode rewards: 339, Reward: 221.45631523879052
# Episode rewards: 340, Reward: 186.0894619112768
# Episode rewards: 341, Reward: 177.82678082036972
# Episode rewards: 342, Reward: 222.26589807246947
# Episode rewards: 343, Reward: 213.62392860224767
# Episode rewards: 344, Reward: 240.48678967193635
# Episode rewards: 345, Reward: 235.5432687014837
# Episode rewards: 346, Reward: 208.57569190901336
# Episode rewards: 347, Reward: 128.26830316181042
# Episode rewards: 348, Reward: 194.061904019319
# Episode rewards: 349, Reward: 215.96369986809557
# Episode rewards: 350, Reward: 202.8645991167345
# Episode rewards: 351, Reward: 227.32302344385553
# Episode rewards: 352, Reward: 27.774413435031317
# Episode rewards: 353, Reward: 215.06672007379353
# Episode rewards: 354, Reward: 216.71003921592182
# Episode rewards: 355, Reward: 225.24366344626446
# Episode rewards: 356, Reward: 213.8544467640545
# Episode rewards: 357, Reward: -33.82693272950084
# Episode rewards: 358, Reward: 53.50057271314352
# Episode rewards: 359, Reward: 202.08719143675182
# Episode rewards: 360, Reward: 158.23076065333487
# Episode rewards: 361, Reward: 188.6635816524659
# Episode rewards: 362, Reward: 182.89110013793052
# Episode rewards: 363, Reward: 131.86593162665898
# Episode rewards: 364, Reward: 233.42764310096717
# Episode rewards: 365, Reward: -7.744499500911277
# Episode rewards: 366, Reward: -3.1634622106905157
# Episode rewards: 367, Reward: 223.25081891988373
# Episode rewards: 368, Reward: 207.20654830130863
# Episode rewards: 369, Reward: 197.97703745645816
# Episode rewards: 370, Reward: 186.11036384969714
# Episode rewards: 371, Reward: 205.21343727285196
# Episode rewards: 372, Reward: 224.99693303235392
# Episode rewards: 373, Reward: 232.00969134373864
# Episode rewards: 374, Reward: 157.25702664113072
# Episode rewards: 375, Reward: 191.38658485097733
# Episode rewards: 376, Reward: 200.55234415031768
# Episode rewards: 377, Reward: 158.97034103357097
# Episode rewards: 378, Reward: 205.57112175008714
# Episode rewards: 379, Reward: 233.52960965968154
# Episode rewards: 380, Reward: 212.20247834521612
# Episode rewards: 381, Reward: 132.4922263836289
# Episode rewards: 382, Reward: 201.79647721712985
# Episode rewards: 383, Reward: 138.2487493853624
# Episode rewards: 384, Reward: 204.7972204811262
# Episode rewards: 385, Reward: 184.908008916471
# Episode rewards: 386, Reward: 196.41968003351462
# Episode rewards: 387, Reward: 175.6111871949187
# Episode rewards: 388, Reward: 133.69201138256895
# Episode rewards: 389, Reward: 179.20133957342162
# Episode rewards: 390, Reward: 40.7811082487876
# Episode rewards: 391, Reward: 252.46043227096257
# Episode rewards: 392, Reward: 235.1074402380209
# Episode rewards: 393, Reward: -54.663779236180126
# Episode rewards: 394, Reward: 226.5697491276493
# Episode rewards: 395, Reward: 224.42234545722704
# Episode rewards: 396, Reward: -19.07204166799731
# Episode rewards: 397, Reward: 176.64379242891494
# Episode rewards: 398, Reward: 87.63850837721185
# Episode rewards: 399, Reward: 269.43128467894184
# Episode rewards: 400, Reward: -73.24614449534518
# Episode rewards: 401, Reward: 221.72660964589446
# Episode rewards: 402, Reward: 194.48857918660258
# Episode rewards: 403, Reward: 242.71736674157043
# Episode rewards: 404, Reward: 205.68825077113345
# Episode rewards: 405, Reward: 19.718573666207106
# Episode rewards: 406, Reward: 243.10264855463961
# Episode rewards: 407, Reward: 151.29221747558955
# Episode rewards: 408, Reward: 235.1480107052153
# Episode rewards: 409, Reward: 270.280816013048
# Episode rewards: 410, Reward: -40.58562949598064
# Episode rewards: 411, Reward: 225.76409115729138
# Episode rewards: 412, Reward: 213.85314506919016
# Episode rewards: 413, Reward: 204.08980314021898
# Episode rewards: 414, Reward: 219.27400935338088
# Episode rewards: 415, Reward: 226.26627596629507
# Episode rewards: 416, Reward: 168.20605407055132
# Episode rewards: 417, Reward: 165.3545252286214
# Episode rewards: 418, Reward: 144.16067274402033
# Episode rewards: 419, Reward: 64.07653228069934
# Episode rewards: 420, Reward: -0.014552698042776813
# Episode rewards: 421, Reward: -37.0094530146099
# Episode rewards: 422, Reward: 56.30464864160693
# Episode rewards: 423, Reward: 235.07070479896788
# Episode rewards: 424, Reward: -263.50070762199636
# Episode rewards: 425, Reward: 209.4527156963795
# Episode rewards: 426, Reward: 243.30430818606993
# Episode rewards: 427, Reward: -313.8563088258084
# Episode rewards: 428, Reward: -210.68416054445697
# Episode rewards: 429, Reward: -175.65953688629008
# Episode rewards: 430, Reward: -200.73723169347107
# Episode rewards: 431, Reward: 87.27948861724775
# Episode rewards: 432, Reward: 216.7165092514651
# Episode rewards: 433, Reward: 192.4165196378696
# Episode rewards: 434, Reward: 272.06688131328315
# Episode rewards: 435, Reward: -187.50704261023253
# Episode rewards: 436, Reward: 277.1226171474745
# Episode rewards: 437, Reward: 260.48868595001
# Episode rewards: 438, Reward: 258.3710092058482
# Episode rewards: 439, Reward: 217.3988403085767
# Episode rewards: 440, Reward: 20.513368399905715
# Episode rewards: 441, Reward: 37.11641501648718
# Episode rewards: 442, Reward: 244.95795276132876
# Episode rewards: 443, Reward: 210.74917297135963
# Episode rewards: 444, Reward: 206.61262657196676
# Episode rewards: 445, Reward: 234.22949781719657
# Episode rewards: 446, Reward: 267.92031511558343
# Episode rewards: 447, Reward: 12.639298777714295
# Episode rewards: 448, Reward: 219.12431359496384
# Episode rewards: 449, Reward: -195.14995618464184
# Episode rewards: 450, Reward: 185.55924820658788
# Episode rewards: 451, Reward: -231.71072767894918
# Episode rewards: 452, Reward: 244.72110981449686
# Episode rewards: 453, Reward: 208.89832481121164
# Episode rewards: 454, Reward: 214.2607119122511
# Episode rewards: 455, Reward: 211.87550822204358
# Episode rewards: 456, Reward: 259.7402736855046
# Episode rewards: 457, Reward: 237.53419800423742
# Episode rewards: 458, Reward: 44.93583746192117
# Episode rewards: 459, Reward: 200.7658981763721
# Episode rewards: 460, Reward: 172.83587254790024
# Episode rewards: 461, Reward: 232.8544290172903
# Episode rewards: 462, Reward: 251.04655106007496
# Episode rewards: 463, Reward: 183.73565727330868
# Episode rewards: 464, Reward: 229.2300700227242
# Episode rewards: 465, Reward: 242.42265313040093
# Episode rewards: 466, Reward: -0.366847554786331
# Episode rewards: 467, Reward: 186.74572931142984
# Episode rewards: 468, Reward: 217.78252429637703
# Episode rewards: 469, Reward: 197.1619562034671
# Episode rewards: 470, Reward: 252.4630619291155
# Episode rewards: 471, Reward: 238.75097443783923
# Episode rewards: 472, Reward: 197.5001641725966
# Episode rewards: 473, Reward: 226.16672048463752
# Episode rewards: 474, Reward: 122.522337661892
# Episode rewards: 475, Reward: 257.4046502284033
# Episode rewards: 476, Reward: 212.7928977932483
# Episode rewards: 477, Reward: 176.50272933137785
# Episode rewards: 478, Reward: 219.25385549082262
# Episode rewards: 479, Reward: 229.29984998371347
# Episode rewards: 480, Reward: 230.69328534771995
# Episode rewards: 481, Reward: 257.08988698806456
# Episode rewards: 482, Reward: 218.0134285997667
# Episode rewards: 483, Reward: 198.06540414075943
# Episode rewards: 484, Reward: 143.02246452990752
# Episode rewards: 485, Reward: 252.79967446805225
# Episode rewards: 486, Reward: 149.29404325653064
# Episode rewards: 487, Reward: 252.91704876890168
# Episode rewards: 488, Reward: 247.67138256730715
# Episode rewards: 489, Reward: 238.9916298622126
# Episode rewards: 490, Reward: 259.7864603355572
# Episode rewards: 491, Reward: 230.08414048378592
# Episode rewards: 492, Reward: 249.50415922183913
# Episode rewards: 493, Reward: 236.229931409123
# Episode rewards: 494, Reward: 195.37530705517864
# Episode rewards: 495, Reward: 226.76822213868695
# Episode rewards: 496, Reward: 220.83469567356616
# Episode rewards: 497, Reward: 230.7699446539005
# Episode rewards: 498, Reward: 206.3707237238965
# Episode rewards: 499, Reward: 192.7101146600499
# Episode rewards: 500, Reward: 193.72483330540257
# Episode rewards: 501, Reward: 211.63390299126144
# Episode rewards: 502, Reward: 254.028276799089
# Episode rewards: 503, Reward: 245.7477977463331
# Episode rewards: 504, Reward: 191.1367608755719
# Episode rewards: 505, Reward: 214.2441385923123
# Episode rewards: 506, Reward: 243.2851221943049
# Episode rewards: 507, Reward: 222.8887611997376
# Episode rewards: 508, Reward: 243.08920308481783
# Episode rewards: 509, Reward: 224.70663629916373
# Episode rewards: 510, Reward: 221.05964383635862
# Episode rewards: 511, Reward: 218.23153319040452
# Episode rewards: 512, Reward: 230.5073757096802
# Episode rewards: 513, Reward: 238.13803343571362
# Episode rewards: 514, Reward: 249.19701851850394
# Episode rewards: 515, Reward: 232.87771599464324
# Episode rewards: 516, Reward: 244.069648178505
# Episode rewards: 517, Reward: 203.94066480813524
# Episode rewards: 518, Reward: 243.02540262365298
# Episode rewards: 519, Reward: 220.86139112187897
# Episode rewards: 520, Reward: 233.3432479841763
# Episode rewards: 521, Reward: 235.10867275936832
# Episode rewards: 522, Reward: 256.6201799325015
# Episode rewards: 523, Reward: 238.30713186740232
# Episode rewards: 524, Reward: 235.03926094081822
# Episode rewards: 525, Reward: 250.92250392611913
# Episode rewards: 526, Reward: 211.57957342682522
# Episode rewards: 527, Reward: 250.26583119651684
# Episode rewards: 528, Reward: 229.87228851083614
# Episode rewards: 529, Reward: 207.95429011145237
# Episode rewards: 530, Reward: 222.6174473706329
# TARGET_REWARD Achieved!

# %% [markdown]
# ### TEST

# %%
import gym
import torch
import numpy as np
import mlflow
import matplotlib.pyplot as plt

# Load environment
env = gym.make('LunarLanderContinuous-v2', render_mode='human')

# Get environment details
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])

# Load trained agent
# agent = DDPG_Agent(state_dim, action_dim, max_action)
agent = TD3_Agent(state_dim, action_dim, max_action)
actor_path = f'./models/{TRAIN_RUN_NAME}.pth'
agent.actor.load_state_dict(torch.load(actor_path))
agent.actor.eval() 

# Set MLflow tracking
mlflow.set_tracking_uri("file:./mlruns")

try:
    if mlflow.active_run():
        run_id = mlflow.active_run().info.run_id
        print(f"Attempting to end active run: {run_id}")
        mlflow.end_run()
except Exception as e:
    print(f"Warning: Tried to end an inactive run. Skipping. Error: {e}")

TEST_RUN_NAME = f"{NAME}__test"

with mlflow.start_run(run_name=TEST_RUN_NAME, nested=True):
    mlflow.log_param("test_episodes", 100)
    
    test_rewards = []
    
    for episode in range(100):
        state, _ = env.reset()
        episode_reward = 0

        while True:
            action = agent.select_action(state, noise=0)  # No exploration noise during testing
            next_state, reward, done, _, _ = env.step(action)
            episode_reward += reward
            state = next_state
            if done:
                break

        test_rewards.append(episode_reward)
        avg_last_10_rewards = np.mean(reward_history[-10:])
        

        mlflow.log_metric('test_episode_reward', episode_reward, step=episode)
        # mlflow.log_metric('test_avg_last_10_rewards', avg_last_10_rewards, step=episode)

        print(f"Test Episode {episode+1}: Reward = {episode_reward}")

    env.close()
